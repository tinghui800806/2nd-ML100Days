# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error():
    """
    請完成這個 Function 後往下執行
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.740

# %%
def mean_square_error(y, yp):

    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 202.194

# %% [markdown]
# TOPIC1:Titanic: Machine Learning from Disaster
# 你選的這組資料為何重要：　titanic的船難是一個歷史借鏡,如果能系統性的分析此次事件,就能提前規畫及準備足夠的救護資源針對下次乘船乘客的資訊
# 資料從何而來：大英博物館（資料來源：csv檔)
# 蒐集而來的資料型態為何:表格形式,需要檢視欄欄位意義以及名稱
# 這組資料想解決的問題如何評估:定義衡量指標AUC

# %% [markdown]
# TOPIC2:如何提升自由車隊的業績
# 核心問題為何:目前的自由載客車隊中,業績做得最好的車是如何做到,它的特色是什麼?找出跟業績正相關的最大相關因素,並針對相關因素投入資源以提升業績
# 資料從何而來:車行的資料能找出各個駕駛者的車型,車齡,性別以及業績（資料來源：csv檔)
#             車行合作的app平台能提供各個駕駛空車的時段以及熱門載客時段與路段(網路爬蟲)
# 蒐集而來的資料型態為何:表格形式,需要檢視欄欄位意義以及名稱
# 這組資料想解決的問題如何評估:定義衡量指標MAE
